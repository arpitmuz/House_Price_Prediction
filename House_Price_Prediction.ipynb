# %%
import pandas as pd
import matplotlib.pyplot as plt

dataset=pd.read_csv("data.csv")

# %%
dataset.head()
# Out:
#    AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  PARK_FACIL  \
# 0     4      1004            131        1.0         1.0       3           1
# 1     1      1986             26        2.0         1.0       5           0
# 2     0       909             70        1.0         1.0       3           1
# 3     7      1855             14        3.0         2.0       5           0
# 4     4      1226             84        1.0         1.0       3           1
#
#    BUILDTYPE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  \
# 0          0       4.0          3.9         4.9       4.330   380000  144400
# 1          0       4.9          4.2         2.5       3.765   760122  304049
# 2          0       4.1          3.8         2.2       3.090   421094   92114
# 3          2       4.7          3.9         3.6       4.010   356321   77042
# 4          2       3.0          2.5         4.1       3.290   237000   74063
#
# ...

# %%
dataset.shape
# Out:
# (7109, 19)

# %%
dataset.isnull().sum()
# Out:
# AREA             0
# INT_SQFT         0
# DIST_MAINROAD    0
# N_BEDROOM        0
# N_BATHROOM       0
# N_ROOM           0
# PARK_FACIL       0
# BUILDTYPE        0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# REG_FEE          0
# COMMIS           0
# SALE_YEAR        0
# SALE_MONTH       0
# BUILD_YEAR       0
# BUILD_AGE        0
# SALES_PRICE      0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AREA           7109 non-null   int64
#  1   INT_SQFT       7109 non-null   int64
#  2   DIST_MAINROAD  7109 non-null   int64
#  3   N_BEDROOM      7109 non-null   float64
#  4   N_BATHROOM     7109 non-null   float64
#  5   N_ROOM         7109 non-null   int64
#  6   PARK_FACIL     7109 non-null   int64
#  7   BUILDTYPE      7109 non-null   int64
#  8   QS_ROOMS       7109 non-null   float64
#  9   QS_BATHROOM    7109 non-null   float64
#  10  QS_BEDROOM     7109 non-null   float64
#  11  QS_OVERALL     7109 non-null   float64
#  12  REG_FEE        7109 non-null   int64
#  13  COMMIS         7109 non-null   int64
#  14  SALE_YEAR      7109 non-null   int64
#  15  SALE_MONTH     7109 non-null   int64
#  16  BUILD_YEAR     7109 non-null   int64
# ...

# %%
dataset.describe()
# Out:
#               AREA     INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM  \
# count  7109.000000  7109.000000    7109.000000  7109.000000  7109.000000
# mean      3.098045  1382.073006      99.603179     1.637029     1.213260
# std       2.083062   457.410902      57.403110     0.802845     0.409495
# min       0.000000   500.000000       0.000000     1.000000     1.000000
# 25%       2.000000   993.000000      50.000000     1.000000     1.000000
# 50%       3.000000  1373.000000      99.000000     1.000000     1.000000
# 75%       4.000000  1744.000000     148.000000     2.000000     1.000000
# max       7.000000  2500.000000     200.000000     4.000000     2.000000
#
#             N_ROOM   PARK_FACIL    BUILDTYPE     QS_ROOMS  QS_BATHROOM  \
# count  7109.000000  7109.000000  7109.000000  7109.000000  7109.000000
# mean      3.688704     0.504572     1.000985     3.517471     3.507244
# std       1.019099     0.500014     0.810125     0.891972     0.897834
# ...

# %%
dataset.hist(bins=20,figsize=(15,20))
plt.show()

# %%
corr_matrix=dataset.corr()
corr_matrix
# Out:
#                    AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# AREA           1.000000  0.362262      -0.018747   0.379879    0.221645
# INT_SQFT       0.362262  1.000000       0.002022   0.786340    0.515261
# DIST_MAINROAD -0.018747  0.002022       1.000000  -0.002565    0.001969
# N_BEDROOM      0.379879  0.786340      -0.002565   1.000000    0.755055
# N_BATHROOM     0.221645  0.515261       0.001969   0.755055    1.000000
# N_ROOM         0.291266  0.951279       0.002301   0.840280    0.568564
# PARK_FACIL     0.012064  0.004618      -0.009448  -0.009470   -0.013965
# BUILDTYPE     -0.009561 -0.006329      -0.014235  -0.002262   -0.003149
# QS_ROOMS       0.004976  0.019850       0.002237   0.015109    0.013108
# QS_BATHROOM   -0.001117 -0.008337      -0.029468  -0.007635   -0.012055
# QS_BEDROOM     0.001465  0.008865       0.001554   0.015566    0.013190
# QS_OVERALL     0.004964  0.013989      -0.017255   0.014172    0.007877
# ...

# %%
corr_matrix["SALES_PRICE"].sort_values(ascending=False)
# Out:
# SALES_PRICE      1.000000
# REG_FEE          0.878148
# COMMIS           0.626275
# INT_SQFT         0.612125
# N_ROOM           0.602760
# N_BEDROOM        0.330999
# PARK_FACIL       0.146428
# BUILD_YEAR       0.116043
# N_BATHROOM       0.108865
# QS_ROOMS         0.021967
# QS_OVERALL       0.020485
# QS_BEDROOM       0.018804
# DIST_MAINROAD    0.018783
# SALE_YEAR        0.000906
# SALE_MONTH      -0.006982
# QS_BATHROOM     -0.011377
# AREA            -0.013842
# BUILD_AGE       -0.118842
# BUILDTYPE       -0.436276
# Name: SALES_PRICE, dtype: float64

# %%
import seaborn as sns
sns.distplot(dataset['REG_FEE'])
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Temp\ipykernel_27080\1198830426.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['REG_FEE'])
# <Axes: xlabel='REG_FEE', ylabel='Density'>

# %%
q1=dataset['REG_FEE'].quantile(0.25)
q3=dataset['REG_FEE'].quantile(0.75)
IQR=q3-q1
Min_range=q1-(1.5*IQR)
Max_range=q3+(1.5*IQR)
dataset=dataset[(dataset['REG_FEE']<=Max_range)&(dataset['REG_FEE']>=Min_range)]

# %%
# outlier removed
sns.distplot(dataset['REG_FEE'])
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Temp\ipykernel_27080\3098329781.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['REG_FEE'])
# <Axes: xlabel='REG_FEE', ylabel='Density'>

# %%
# outlier present
sns.distplot(dataset['COMMIS'])
plt.show()
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Temp\ipykernel_27080\735793581.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['COMMIS'])

# %%
q1=dataset['COMMIS'].quantile(0.25)
q3=dataset['COMMIS'].quantile(0.75)
IQR=q3-q1
Min_range=q1-(1.5*IQR)
Max_range=q3+(1.5*IQR)
dataset=dataset[(dataset['COMMIS']<=Max_range)&(dataset['COMMIS']>=Min_range)]

# %%
# outlier removed
sns.distplot(dataset['COMMIS'])
plt.show()
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Temp\ipykernel_27080\2329557882.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['COMMIS'])

# %%
sns.distplot(dataset['INT_SQFT'])
plt.show()
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Temp\ipykernel_27080\3991112922.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['INT_SQFT'])

# %%
# outlier present
sns.distplot(dataset['N_ROOM'])
plt.show()
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Temp\ipykernel_27080\819161454.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['N_ROOM'])

# %%
# outlier removed
q1=dataset['N_ROOM'].quantile(0.25)
q3=dataset['N_ROOM'].quantile(0.75)
IQR=q3-q1
Min_range=q1-(1.5*IQR)
Max_range=q3+(1.5*IQR)
dataset=dataset[(dataset['N_ROOM']<=Max_range)&(dataset['N_ROOM']>=Min_range)]
sns.distplot(dataset['N_ROOM'])
plt.show()
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Temp\ipykernel_27080\2359299611.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['N_ROOM'])

# %%
sns.distplot(dataset['N_BEDROOM'])
plt.show()
# NO NEED TO REMOVE THEOUTLIER NO OUTLIER ARE PRESENT
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Temp\ipykernel_27080\3929028119.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['N_BEDROOM'])

# %%
dataset[['AREA','INT_SQFT','N_BEDROOM','N_BATHROOM',]].corr()
# Out:
#                 AREA  INT_SQFT  N_BEDROOM  N_BATHROOM
# AREA        1.000000  0.427430   0.487313    0.247720
# INT_SQFT    0.427430  1.000000   0.737769    0.431200
# N_BEDROOM   0.487313  0.737769   1.000000    0.705757
# N_BATHROOM  0.247720  0.431200   0.705757    1.000000

# %% [markdown]
# # SCALING

# %%
dataset=dataset.reset_index().drop('index',axis=1)

# %%
dataset
# Out:
#       AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0        4      1004            131        1.0         1.0       3
# 1        0       909             70        1.0         1.0       3
# 2        7      1855             14        3.0         2.0       5
# 3        4      1226             84        1.0         1.0       3
# 4        2      1220             36        2.0         1.0       4
# ...    ...       ...            ...        ...         ...     ...
# 6559     4       598             51        1.0         1.0       2
# 6560     7      1897             52        3.0         2.0       5
# 6561     7      1614            152        2.0         1.0       4
# 6562     4       787             40        1.0         1.0       2
# 6563     7      1896            156        3.0         2.0       5
#
#       PARK_FACIL  BUILDTYPE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  \
# 0              1          0       4.0          3.9         4.9        4.33
# ...

# %%
dataset.columns
# Out:
# Index(['AREA', 'INT_SQFT', 'DIST_MAINROAD', 'N_BEDROOM', 'N_BATHROOM',
#        'N_ROOM', 'PARK_FACIL', 'BUILDTYPE', 'QS_ROOMS', 'QS_BATHROOM',
#        'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS', 'SALE_YEAR',
#        'SALE_MONTH', 'BUILD_YEAR', 'BUILD_AGE', 'SALES_PRICE'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
my_pipeline=Pipeline([
    ('MINMAXSCALER',MinMaxScaler()),
     
])
dataset1=my_pipeline.fit_transform(dataset.iloc[:,:18])

# %%
dataset1=pd.DataFrame(dataset1,columns=[['AREA', 'INT_SQFT', 'DIST_MAINROAD', 'N_BEDROOM', 'N_BATHROOM',
       'N_ROOM', 'PARK_FACIL', 'BUILDTYPE', 'QS_ROOMS', 'QS_BATHROOM',
       'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS', 'SALE_YEAR',
       'SALE_MONTH', 'BUILD_YEAR', 'BUILD_AGE']])
dataset1
# Out:
#           AREA  INT_SQFT DIST_MAINROAD N_BEDROOM N_BATHROOM    N_ROOM  \
# 0     0.571429  0.293194         0.655       0.0        0.0  0.333333
# 1     0.000000  0.237929         0.350       0.0        0.0  0.333333
# 2     1.000000  0.788249         0.070       1.0        1.0  1.000000
# 3     0.571429  0.422339         0.420       0.0        0.0  0.333333
# 4     0.285714  0.418848         0.180       0.5        0.0  0.666667
# ...        ...       ...           ...       ...        ...       ...
# 6559  0.571429  0.057010         0.255       0.0        0.0  0.000000
# 6560  1.000000  0.812682         0.260       1.0        1.0  1.000000
# 6561  1.000000  0.648051         0.760       0.5        0.0  0.666667
# 6562  0.571429  0.166958         0.200       0.0        0.0  0.000000
# 6563  1.000000  0.812100         0.780       1.0        1.0  1.000000
#
#      PARK_FACIL BUILDTYPE  QS_ROOMS QS_BATHROOM QS_BEDROOM QS_OVERALL  \
# ...

# %%
dataset1
# Out:
#           AREA  INT_SQFT DIST_MAINROAD N_BEDROOM N_BATHROOM    N_ROOM  \
# 0     0.571429  0.293194         0.655       0.0        0.0  0.333333
# 1     0.000000  0.237929         0.350       0.0        0.0  0.333333
# 2     1.000000  0.788249         0.070       1.0        1.0  1.000000
# 3     0.571429  0.422339         0.420       0.0        0.0  0.333333
# 4     0.285714  0.418848         0.180       0.5        0.0  0.666667
# ...        ...       ...           ...       ...        ...       ...
# 6559  0.571429  0.057010         0.255       0.0        0.0  0.000000
# 6560  1.000000  0.812682         0.260       1.0        1.0  1.000000
# 6561  1.000000  0.648051         0.760       0.5        0.0  0.666667
# 6562  0.571429  0.166958         0.200       0.0        0.0  0.000000
# 6563  1.000000  0.812100         0.780       1.0        1.0  1.000000
#
#      PARK_FACIL BUILDTYPE  QS_ROOMS QS_BATHROOM QS_BEDROOM QS_OVERALL  \
# ...

# %%
dataset.iloc[:,:18]
# Out:
#       AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0        4      1004            131        1.0         1.0       3
# 1        0       909             70        1.0         1.0       3
# 2        7      1855             14        3.0         2.0       5
# 3        4      1226             84        1.0         1.0       3
# 4        2      1220             36        2.0         1.0       4
# ...    ...       ...            ...        ...         ...     ...
# 6559     4       598             51        1.0         1.0       2
# 6560     7      1897             52        3.0         2.0       5
# 6561     7      1614            152        2.0         1.0       4
# 6562     4       787             40        1.0         1.0       2
# 6563     7      1896            156        3.0         2.0       5
#
#       PARK_FACIL  BUILDTYPE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  \
# 0              1          0       4.0          3.9         4.9        4.33
# ...

# %%
m=MinMaxScaler()
y=m.fit_transform(dataset[["SALES_PRICE"]])

# %%
y=pd.DataFrame(y)

# %%
y
# Out:
#              0
# 0     0.263953
# 1     0.533536
# 2     0.362408
# 3     0.254558
# 4     0.496465
# ...        ...
# 6559  0.154990
# 6560  0.420027
# 6561  0.300392
# 6562  0.307937
# 6563  0.379196
#
# [6564 rows x 1 columns]

# %% [markdown]
# # PAC

# %%
dataset1
# Out:
#           AREA  INT_SQFT DIST_MAINROAD N_BEDROOM N_BATHROOM    N_ROOM  \
# 0     0.571429  0.293194         0.655       0.0        0.0  0.333333
# 1     0.000000  0.237929         0.350       0.0        0.0  0.333333
# 2     1.000000  0.788249         0.070       1.0        1.0  1.000000
# 3     0.571429  0.422339         0.420       0.0        0.0  0.333333
# 4     0.285714  0.418848         0.180       0.5        0.0  0.666667
# ...        ...       ...           ...       ...        ...       ...
# 6559  0.571429  0.057010         0.255       0.0        0.0  0.000000
# 6560  1.000000  0.812682         0.260       1.0        1.0  1.000000
# 6561  1.000000  0.648051         0.760       0.5        0.0  0.666667
# 6562  0.571429  0.166958         0.200       0.0        0.0  0.000000
# 6563  1.000000  0.812100         0.780       1.0        1.0  1.000000
#
#      PARK_FACIL BUILDTYPE  QS_ROOMS QS_BATHROOM QS_BEDROOM QS_OVERALL  \
# ...

# %%
from sklearn.decomposition import PCA

pca=PCA(0.95)
pca.fit(dataset1)
# Out:
# PCA(n_components=0.95)

# %%
x_pca=pca.transform(dataset1)

# %%
x_pca.shape
# Out:
# (6564, 12)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.21625664, 0.15605861, 0.10383865, 0.07408531, 0.06944889,
#        0.06457195, 0.05635741, 0.05530347, 0.05433841, 0.05088517,
#        0.04002919, 0.02375115])

# %%
x_pca
# Out:
# array([[-0.3002435 ,  0.51408295, -0.54499707, ...,  0.14398047,
#         -0.04211556,  0.15925923],
#        [-0.55376305,  0.51770544, -0.497145  , ..., -0.15945232,
#         -0.20309821,  0.00715345],
#        [ 1.26115221, -0.53707837,  0.54258603, ..., -0.46457847,
#          0.30351011,  0.05394861],
#        ...,
#        [ 0.36242818, -0.49807466, -0.06082446, ...,  0.27509196,
#          0.39033753, -0.1927153 ],
#        [-0.50049413,  0.5174098 , -0.5427847 , ..., -0.32868197,
#          0.19830202,  0.01383699],
#        [ 1.33553536,  0.44562658,  0.54445678, ...,  0.30518758,
#          0.11494229, -0.29821387]])

# %%
pca.transform([[1, 2, 3 ,4 ,5, 6, 7, 8 ,9 ,12, 13, 14, 15 ,12 ,13 ,14,15,43]])
# Out:
# array([[ 12.09074923,   7.19134739,   3.37374376,  25.36327945,
#          13.45031355,   5.93355165,  -2.03066161,  -1.22500169,
#          -1.76453926,   6.44551106, -18.28666624,  21.62196827]])

# %%
pca_columns = [f'PC{i+1}' for i in range(x_pca.shape[1])] 
x_pca = pd.DataFrame(x_pca, columns=pca_columns)

# %%
x_pca
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -0.300243  0.514083 -0.544997  0.544961  0.369445 -0.228546  0.104446
# 1    -0.553763  0.517705 -0.497145 -0.190335 -0.291698 -0.328281  0.265811
# 2     1.261152 -0.537078  0.542586  0.312617 -0.100070 -0.268091  0.292084
# 3    -0.335479  0.479972  0.510974 -0.125456  0.323077  0.310954 -0.112091
# 4     0.025019 -0.470834 -0.544250 -0.113885 -0.512721  0.334062 -0.296830
# ...        ...       ...       ...       ...       ...       ...       ...
# 6559 -0.604534 -0.505465  0.469151 -0.619486  0.604245 -0.538970  0.282593
# 6560  1.355692  0.478204  0.518695  0.171524 -0.210441 -0.157710  0.165090
# 6561  0.362428 -0.498075 -0.060824  0.213979  0.422934 -0.028273 -0.333595
# 6562 -0.500494  0.517410 -0.542785  0.475036  0.324524  0.117102  0.185454
# 6563  1.335535  0.445627  0.544457  0.098662  0.510543  0.017319  0.322574
#
#            PC8       PC9      PC10      PC11      PC12
# ...

# %%
pca.components_
#This matrix contains the loadings for each principal component (each row corresponds to a principal component, and each column corresponds to an original feature).
# Out:
# array([[ 2.82671675e-01,  3.50093869e-01, -3.13591097e-03,
#          5.26413796e-01,  5.02238249e-01,  4.57128456e-01,
#          3.66359731e-03,  2.91278272e-03,  1.50083458e-02,
#         -2.58408557e-03,  1.09985947e-02,  8.24946020e-03,
#          1.49937473e-01,  1.64537379e-01, -7.52456496e-02,
#          1.12594685e-03, -4.58718821e-02,  3.78938973e-02],
#        [ 5.29535930e-03,  2.79793717e-03, -8.67829534e-03,
#         -1.50476149e-02, -2.77073298e-02, -2.97425069e-03,
#          9.96033510e-01, -1.22073199e-02, -3.02277613e-03,
#         -4.51289156e-03,  9.52372223e-04, -1.51777956e-03,
#          6.19321797e-02,  5.05306442e-02, -3.63231316e-04,
#         -1.26451002e-02,  5.48145978e-03, -6.50701136e-03],
#        [-1.76637440e-02,  1.46742532e-02, -2.81462854e-02,
#          3.18661555e-02,  4.08034511e-02,  2.33199428e-02,
#          3.12108121e-02,  9.71485383e-01, -1.10691130e-02,
#          4.53727456e-03, -8.33279326e-03, -5.85694430e-03,
# ...

# %%
x_train1,x_test1,y_train1,y_test1 = train_test_split(dataset.iloc[:,:-1],dataset.iloc[:,-1],test_size=.4,random_state=42)

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(x_pca,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 2775 -0.100584 -0.512557  0.480643 -0.123798  0.462314  0.312455 -0.365095
# 2678  0.218873 -0.450373 -0.603098 -0.209766 -0.032374 -0.080365 -0.286606
# 1954  1.267257  0.496083 -0.023901 -0.155891 -0.483005  0.391922  0.133476
# 3764  0.240966 -0.482769 -0.096118  0.001236 -0.057049  0.041228 -0.342863
# 4814  1.145813 -0.531520  0.022674  0.595097 -0.173383  0.165523  0.373463
# ...        ...       ...       ...       ...       ...       ...       ...
# 3772 -0.171373 -0.488012  0.416350  0.194159 -0.478308 -0.009007 -0.337786
# 5191  0.656431  0.479274 -0.443157 -0.349224  0.040336 -0.363734  0.748790
# 5226  0.448818  0.548225 -0.599956  0.448657 -0.002288 -0.424154 -0.379988
# 5390 -0.562943 -0.495577 -0.533122  0.159436  0.350469 -0.067232  0.260225
# 860  -0.611868  0.480996  0.001484  0.552220  0.552709 -0.504827  0.484674
#
#            PC8       PC9      PC10      PC11      PC12
# ...

# %%
x_pca
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -0.300243  0.514083 -0.544997  0.544961  0.369445 -0.228546  0.104446
# 1    -0.553763  0.517705 -0.497145 -0.190335 -0.291698 -0.328281  0.265811
# 2     1.261152 -0.537078  0.542586  0.312617 -0.100070 -0.268091  0.292084
# 3    -0.335479  0.479972  0.510974 -0.125456  0.323077  0.310954 -0.112091
# 4     0.025019 -0.470834 -0.544250 -0.113885 -0.512721  0.334062 -0.296830
# ...        ...       ...       ...       ...       ...       ...       ...
# 6559 -0.604534 -0.505465  0.469151 -0.619486  0.604245 -0.538970  0.282593
# 6560  1.355692  0.478204  0.518695  0.171524 -0.210441 -0.157710  0.165090
# 6561  0.362428 -0.498075 -0.060824  0.213979  0.422934 -0.028273 -0.333595
# 6562 -0.500494  0.517410 -0.542785  0.475036  0.324524  0.117102  0.185454
# 6563  1.335535  0.445627  0.544457  0.098662  0.510543  0.017319  0.322574
#
#            PC8       PC9      PC10      PC11      PC12
# ...

# %%
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor
rfr=RandomForestRegressor(n_estimators=55,max_depth=15,min_samples_split=3)

rfr.fit(x_train,y_train)
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=15, min_samples_split=3, n_estimators=55)

# %%
rfr.score(x_test,y_test)*100,rfr.score(x_train,y_train)*100
# Out:
# (89.98866070733497, 98.24868083737368)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test),lr.score(x_train,y_train)
# Out:
# (0.7626749572713929, 0.7495401727687269)

# %%
from sklearn.linear_model import Lasso
ls=Lasso(alpha=0.001)
ls.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.001)

# %%
ls.score(x_test,y_test),ls.score(x_train,y_train)
# Out:
# (0.7563555228206635, 0.745401161985526)

# %%
from sklearn.linear_model import Ridge
rg=Ridge(alpha=15)
rg.fit(x_train,y_train)
# Out:
# Ridge(alpha=15)

# %%
rg.score(x_test,y_test)
# Out:
# 0.7610358715667819

# %%
y.shape
# Out:
# (6564, 1)

# %%
x_train1
# Out:
#       AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 2218     3      1759            104        2.0         1.0       4
# 5812     4      1230             93        1.0         1.0       3
# 2121     0       635            134        1.0         1.0       2
# 3213     2       946             45        1.0         1.0       3
# 5049     2       879             19        1.0         1.0       3
# ...    ...       ...            ...        ...         ...     ...
# 3772     1      1626            155        1.0         1.0       4
# 5191     4      1428            123        2.0         2.0       4
# 5226     7      1674            103        2.0         1.0       4
# 5390     4       748            105        1.0         1.0       2
# 860      4       527            147        1.0         1.0       2
#
#       PARK_FACIL  BUILDTYPE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  \
# 2218           0          2       3.0          4.1         3.7       3.610
# ...

# %%
x_test1
# Out:
#       AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 1433     5      1512            163        1.0         1.0       4
# 1558     3      1399            184        2.0         1.0       4
# 4240     2      1300            111        2.0         1.0       4
# 6003     2       820            116        1.0         1.0       3
# 1374     7      1940             89        3.0         2.0       5
# ...    ...       ...            ...        ...         ...     ...
# 4786     3      1307             39        1.0         1.0       3
# 871      1      1866            137        2.0         1.0       5
# 6009     2      1000             80        1.0         1.0       3
# 3165     4      1434            166        2.0         2.0       4
# 2825     7      1690             28        2.0         1.0       4
#
#       PARK_FACIL  BUILDTYPE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  \
# 1433           1          0       2.1          4.4         4.0       3.530
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
pipeline=Pipeline([
     
    ('Scaler',my_pipeline),
    ('PCA',pca),
    ('RFR',rfr)
])
pipeline.fit(x_train1,y_train1)
y_pred = pipeline.predict(x_test1)

# %%
pipeline.predict([[4,	1004	,131,	1.0,	1.0,	3,	1,	0,	4.0,	3.9,	4.9,4.33,380000,144400	,2011,	5	,1967	,44	]])
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# array([8351840.13636364])

# %%
print('R2 Score',r2_score(y_test1,y_pred))
print('MAE',mean_absolute_error(y_test1,y_pred))
# Out:
# R2 Score 0.8990299249668781
# MAE 819395.9535620213

# %%
dataset.head()
# Out:
#    AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  PARK_FACIL  \
# 0     4      1004            131        1.0         1.0       3           1
# 1     0       909             70        1.0         1.0       3           1
# 2     7      1855             14        3.0         2.0       5           0
# 3     4      1226             84        1.0         1.0       3           1
# 4     2      1220             36        2.0         1.0       4           0
#
#    BUILDTYPE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  \
# 0          0       4.0          3.9         4.9        4.33   380000  144400
# 1          0       4.1          3.8         2.2        3.09   421094   92114
# 2          2       4.7          3.9         3.6        4.01   356321   77042
# 3          2       3.0          2.5         4.1        3.29   237000   74063
# 4          0       4.5          2.6         3.1        3.32   409027  198316
#
# ...

# %%
pipeline.predict([[0	,909,	70,	1.0,	1.0,	3,	1,	0,	4.1,	3.8,	2.2,	3.09,	421094,	92114,	2012,	2,	1992,	20,	]])
# Out:
# C:\Users\ARPIT AGRAWAL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# array([12637004.60507781])

# %%
import pickle

# %%
pickle.dump(dataset,open('df.pkl','wb'))

# %%
pickle.dump(pipeline,open('pipe.pkl','wb'))
